# %% [markdown]
# # OMxPSG image classification with Transfer Learning - Fine Tuning using VGG16
#
# To implement the OMxPSG t-shirt detection with Haar cascade, we need to train a classification model. Once we've extracted the ROI of the t-shirt, we perform the classification.
#
# For this project, we have $1200$ images in the [dataset](https://github.com/IgorMeloS/OMxPSG-T-Shirt-Detection/tree/main/dataset), $600$ for each team. The total of images is not enough to train a model from scratch, for this reason, we'll to train the model with transfer learning, more specifically, with fine tuning.
#
# Fine is composed by two step, the first of them is similar to the feature extraction. We define the top (or head) of the network to take care about the classification, while the body of the network uses the weights from the pre-trained model to extract features. In this step, the top (or head) of the network does not have access to the body of the network (the base model is not trainable). The top of the network tweaks the weights by itself. The second step is the fine tuning. In this moment the top of the network communicates with the body (partially or completely), tweaking the weights with the pre-trained model.

# %% [markdown]
# ## Importing Libraries

# %%
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from compvis.preprocessing import ImageToArrayPreprocessor
from compvis.preprocessing import ResizeAR
from compvis.datasets import SimpleDatasetLoader
from compvis.nn.cnns import FCHeadNet
from compvis.nn.lr import LRFunc
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from imutils import paths
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

# %% [markdown]
# ## Setting the dataset

# %%
dataset = "/path/to/dataset" # the path for the dataset

# %% [markdown]
# **Making the list of images path**

# %%
imagesPath = list(paths.list_images(dataset))

# %% [markdown]
# **Getting the list of classes names**

# %%
classNames = [pt.split(os.path.sep)[-2] for pt in imagesPath] # Splitting the class from the path
classNames = [str(x) for x in np.unique(classNames)]

# %% [markdown]
# ### Loading and preprocessing the images
#
# The VGG16 requires input images with $(224,224)$, for this reason, we must resize all images. To have a good performance, we consider the resize process conserving the aspect ratio.

# %%
ar = ResizeAR(224, 224) # resizing with aspect ratio
iap = ImageToArrayPreprocessor()

# %%
dl = SimpleDatasetLoader([ar, iap]) # defining the data loader
(data, labels) = dl.load(imagesPath, verbose=500) # loading the images
data = data.astype("float") / 255. # scaling into 0 and 1
# Out:
# [INFO] processed 500/1200
# [INFO] processed 1000/1200

# %% [markdown]
# ### Splitting the dataset into training and test set

# %%
(X_train, X_val, y_train, y_val) = train_test_split(data, labels, test_size=0.25, random_state=42)

# %% [markdown]
# **Enconding the targets**

# %%
le = LabelBinarizer()
y_train = le.fit_transform(y_train)
y_val = le.fit_transform(y_val)

# %%
le.classes_
# Out:
# array(['OM', 'PSG'], dtype='<U3')

# %% [markdown]
# ## Building the model
#
# The model is composed by two components, the base model (backbone) and the Head function (classification).

# %%
baseModel = VGG16(weights = "imagenet", include_top = False,
                 input_tensor = Input(shape=(224, 224, 3))) # backbone

# %%
FC = FCHeadNet.build(baseModel, len(classNames), 256) #Function head

# %%
model = Model(inputs = baseModel.input, outputs = FC)

# %% [markdown]
# ### Freezing the convolutional layers from VGG16
#
# In the first step of the training, we freeze the base model, it works as a feature extractor.

# %%
for layer in baseModel.layers:
    layer.trainable = False

# %% [markdown]
# **Optimizer and regulation**

# %%
aug = ImageDataGenerator(rotation_range = 30, width_shift_range = 0.1,
                         height_shift_range = 0.1, shear_range = 0.2,
                         horizontal_flip = True, fill_mode = "nearest")

# %%
opt = RMSprop(lr = 0.001)

# %%
model.compile(loss= "binary_crossentropy", optimizer = opt, metrics = ["accuracy"])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               6422784
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 21,137,729
# Trainable params: 6,423,041
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ## Training without fine tuning
#
# We train the model over 25 epochs, RMSprop as regularization with initial learn rate of $0.001$. The batch size is $32$.

# %%
H = model.fit(aug.flow(X_train, y_train, batch_size=32), validation_data = (X_val, y_val),
             epochs = 25, steps_per_epoch = len(X_train) // 32,
             verbose = 1)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 28 steps, validate on 300 samples
# Epoch 1/25
# 28/28 [==============================] - 12s 431ms/step - loss: 3.3932 - accuracy: 0.6279 - val_loss: 0.2859 - val_accuracy: 0.8633
# Epoch 2/25
# 28/28 [==============================] - 9s 333ms/step - loss: 0.6727 - accuracy: 0.7224 - val_loss: 0.2358 - val_accuracy: 0.9100
# Epoch 3/25
# 28/28 [==============================] - 9s 325ms/step - loss: 0.5418 - accuracy: 0.7765 - val_loss: 0.2320 - val_accuracy: 0.8900
# Epoch 4/25
# 28/28 [==============================] - 9s 327ms/step - loss: 0.3990 - accuracy: 0.8168 - val_loss: 0.1728 - val_accuracy: 0.9200
# Epoch 5/25
# 28/28 [==============================] - 9s 318ms/step - loss: 0.3837 - accuracy: 0.8272 - val_loss: 0.2478 - val_accuracy: 0.8933
# Epoch 6/25
# 28/28 [==============================] - 9s 333ms/step - loss: 0.3208 - accuracy: 0.8687 - val_loss: 0.1663 - val_accuracy: 0.9467
# Epoch 7/25
# 28/28 [==============================] - 9s 334ms/step - loss: 0.3179 - accuracy: 0.8606 - val_loss: 0.2923 - val_accuracy: 0.8700
# Epoch 8/25
# 28/28 [==============================] - 9s 331ms/step - loss: 0.2689 - accuracy: 0.8975 - val_loss: 0.2473 - val_accuracy: 0.8733
# Epoch 9/25
# 28/28 [==============================] - 9s 337ms/step - loss: 0.3009 - accuracy: 0.8744 - val_loss: 0.1976 - val_accuracy: 0.9167
# Epoch 10/25
# 28/28 [==============================] - 9s 324ms/step - loss: 0.2540 - accuracy: 0.8986 - val_loss: 0.1205 - val_accuracy: 0.9433
# Epoch 11/25
# 28/28 [==============================] - 9s 328ms/step - loss: 0.2875 - accuracy: 0.8871 - val_loss: 0.1312 - val_accuracy: 0.9267
# Epoch 12/25
# 28/28 [==============================] - 9s 326ms/step - loss: 0.1806 - accuracy: 0.9263 - val_loss: 0.1640 - val_accuracy: 0.9167
# Epoch 13/25
# 28/28 [==============================] - 9s 323ms/step - loss: 0.1731 - accuracy: 0.9355 - val_loss: 0.1319 - val_accuracy: 0.9433
# Epoch 14/25
# 28/28 [==============================] - 9s 324ms/step - loss: 0.1923 - accuracy: 0.9297 - val_loss: 0.1810 - val_accuracy: 0.9267
# Epoch 15/25
# 28/28 [==============================] - 10s 347ms/step - loss: 0.1885 - accuracy: 0.9240 - val_loss: 0.1330 - val_accuracy: 0.9467
# Epoch 16/25
# 28/28 [==============================] - 9s 329ms/step - loss: 0.2049 - accuracy: 0.9182 - val_loss: 0.0864 - val_accuracy: 0.9500
# Epoch 17/25
# 28/28 [==============================] - 9s 318ms/step - loss: 0.2065 - accuracy: 0.9263 - val_loss: 0.0927 - val_accuracy: 0.9533
# Epoch 18/25
# 28/28 [==============================] - 9s 324ms/step - loss: 0.1391 - accuracy: 0.9493 - val_loss: 0.2314 - val_accuracy: 0.9233
# Epoch 19/25
# 28/28 [==============================] - 9s 319ms/step - loss: 0.1879 - accuracy: 0.9332 - val_loss: 0.1901 - val_accuracy: 0.9200
# Epoch 20/25
# 28/28 [==============================] - 9s 325ms/step - loss: 0.1429 - accuracy: 0.9459 - val_loss: 0.0946 - val_accuracy: 0.9600
# Epoch 21/25
# 28/28 [==============================] - 9s 324ms/step - loss: 0.1688 - accuracy: 0.9475 - val_loss: 0.1351 - val_accuracy: 0.9367
# Epoch 22/25
# 28/28 [==============================] - 9s 331ms/step - loss: 0.0964 - accuracy: 0.9735 - val_loss: 0.0909 - val_accuracy: 0.9600
# Epoch 23/25
# 28/28 [==============================] - 9s 322ms/step - loss: 0.1557 - accuracy: 0.9459 - val_loss: 0.1085 - val_accuracy: 0.9500
# Epoch 24/25
# 28/28 [==============================] - 9s 333ms/step - loss: 0.1052 - accuracy: 0.9597 - val_loss: 0.1176 - val_accuracy: 0.9433
# Epoch 25/25
# 28/28 [==============================] - 10s 341ms/step - loss: 0.1473 - accuracy: 0.9482 - val_loss: 0.1399 - val_accuracy: 0.9333

# %% [markdown]
# ## Visualizing the results on the validation set without fine tuning

# %%
import tensorflow as tf

# %%
predictions = model.predict(X_val, batch_size=32)
predictions = tf.where(predictions < 0.5, 0, 1)

# %%
print(classification_report(y_val, predictions, target_names=classNames))
# Out:
#               precision    recall  f1-score   support
#
#           OM       0.99      0.88      0.93       152
#          PSG       0.89      0.99      0.94       148
#
#     accuracy                           0.93       300
#    macro avg       0.94      0.93      0.93       300
# weighted avg       0.94      0.93      0.93       300

# %%
import matplotlib.pyplot as plt

# %%
acc = H.history['accuracy']
val_acc = H.history['val_accuracy']

loss = H.history['loss']
val_loss = H.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ## Training with fine tuning
#
# The second step of training process is the moment of the fine tuning. We unfreeze a certain number of layers and, the weights from these unfreeze layers will be tweaked with the head of the model. In this case, we unfreeze the last convolutional block.
#
# To avoid over-fit, we consider a step function to drop down slightly the learning rate every $10$ epochs. In addition, we change the regularization into SGD with initial learn rate of $0.001$. The total of epochs is $50$.

# %%
for layer in baseModel.layers[15:]:
    layer.trainable = True #unfreezing

# %%
callbacks = [LearningRateScheduler(LRFunc.step_decay)] #defining the step function decay

# %%
opt = SGD()
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"]) #compiling the model

# %%
H_fine = model.fit(aug.flow(X_train, y_train, batch_size=32), 
                             validation_data=(X_val, y_val), epochs=50,
                             callbacks=callbacks,
                             steps_per_epoch=len(X_train) // 32, verbose=1)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 28 steps, validate on 300 samples
# The intitial learning rate is 0.001000
# Epoch 1/50
# 28/28 [==============================] - 10s 353ms/step - loss: 0.0868 - accuracy: 0.9712 - val_loss: 0.0686 - val_accuracy: 0.9667
# Epoch 2/50
# 28/28 [==============================] - 9s 319ms/step - loss: 0.0599 - accuracy: 0.9747 - val_loss: 0.0660 - val_accuracy: 0.9700
# Epoch 3/50
# 28/28 [==============================] - 9s 319ms/step - loss: 0.0412 - accuracy: 0.9862 - val_loss: 0.0611 - val_accuracy: 0.9767
# Epoch 4/50
# 28/28 [==============================] - 9s 319ms/step - loss: 0.0530 - accuracy: 0.9827 - val_loss: 0.0717 - val_accuracy: 0.9633
# Epoch 5/50
# 28/28 [==============================] - 9s 318ms/step - loss: 0.0351 - accuracy: 0.9885 - val_loss: 0.0635 - val_accuracy: 0.9800
# Epoch 6/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.0292 - accuracy: 0.9885 - val_loss: 0.0600 - val_accuracy: 0.9800
# Epoch 7/50
# 28/28 [==============================] - 9s 321ms/step - loss: 0.0371 - accuracy: 0.9850 - val_loss: 0.0517 - val_accuracy: 0.9867
# Epoch 8/50
# 28/28 [==============================] - 9s 328ms/step - loss: 0.0303 - accuracy: 0.9873 - val_loss: 0.0539 - val_accuracy: 0.9833
# Epoch 9/50
# 28/28 [==============================] - 9s 325ms/step - loss: 0.0343 - accuracy: 0.9850 - val_loss: 0.0529 - val_accuracy: 0.9833
# Epoch 10/50
# 28/28 [==============================] - 9s 318ms/step - loss: 0.0694 - accuracy: 0.9712 - val_loss: 0.0467 - val_accuracy: 0.9767
# Learning rate updated  0.000991
# Epoch 11/50
# 28/28 [==============================] - 9s 316ms/step - loss: 0.0286 - accuracy: 0.9908 - val_loss: 0.0515 - val_accuracy: 0.9733
# Epoch 12/50
# 28/28 [==============================] - 9s 320ms/step - loss: 0.0271 - accuracy: 0.9885 - val_loss: 0.1071 - val_accuracy: 0.9633
# Epoch 13/50
# 28/28 [==============================] - 9s 318ms/step - loss: 0.0203 - accuracy: 0.9919 - val_loss: 0.0485 - val_accuracy: 0.9800
# Epoch 14/50
# 28/28 [==============================] - 9s 319ms/step - loss: 0.0225 - accuracy: 0.9919 - val_loss: 0.0792 - val_accuracy: 0.9700
# Epoch 15/50
# 28/28 [==============================] - 9s 318ms/step - loss: 0.0132 - accuracy: 0.9977 - val_loss: 0.0532 - val_accuracy: 0.9700
# Epoch 16/50
# 28/28 [==============================] - 9s 318ms/step - loss: 0.0185 - accuracy: 0.9931 - val_loss: 0.0766 - val_accuracy: 0.9667
# Epoch 17/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.0289 - accuracy: 0.9839 - val_loss: 0.0575 - val_accuracy: 0.9833
# Epoch 18/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.0182 - accuracy: 0.9919 - val_loss: 0.0589 - val_accuracy: 0.9800
# Epoch 19/50
# 28/28 [==============================] - 9s 321ms/step - loss: 0.0196 - accuracy: 0.9942 - val_loss: 0.0538 - val_accuracy: 0.9800
# Epoch 20/50
# 28/28 [==============================] - 9s 319ms/step - loss: 0.0398 - accuracy: 0.9850 - val_loss: 0.0319 - val_accuracy: 0.9833
# Learning rate updated  0.000981
# Epoch 21/50
# 28/28 [==============================] - 9s 318ms/step - loss: 0.0140 - accuracy: 0.9954 - val_loss: 0.0319 - val_accuracy: 0.9867
# Epoch 22/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.0274 - accuracy: 0.9931 - val_loss: 0.0340 - val_accuracy: 0.9800
# Epoch 23/50
# 28/28 [==============================] - 9s 326ms/step - loss: 0.0259 - accuracy: 0.9931 - val_loss: 0.0613 - val_accuracy: 0.9833
# Epoch 24/50
# 28/28 [==============================] - 9s 321ms/step - loss: 0.0202 - accuracy: 0.9908 - val_loss: 0.0318 - val_accuracy: 0.9900
# Epoch 25/50
# 28/28 [==============================] - 9s 318ms/step - loss: 0.0163 - accuracy: 0.9965 - val_loss: 0.0274 - val_accuracy: 0.9833
# Epoch 26/50
# 28/28 [==============================] - 9s 318ms/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 0.0303 - val_accuracy: 0.9833
# Epoch 27/50
# 28/28 [==============================] - 9s 321ms/step - loss: 0.0087 - accuracy: 0.9977 - val_loss: 0.0293 - val_accuracy: 0.9833
# Epoch 28/50
# 28/28 [==============================] - 9s 320ms/step - loss: 0.0112 - accuracy: 0.9954 - val_loss: 0.0312 - val_accuracy: 0.9900
# Epoch 29/50
# 28/28 [==============================] - 9s 321ms/step - loss: 0.0094 - accuracy: 0.9977 - val_loss: 0.0272 - val_accuracy: 0.9900
# Epoch 30/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.0279 - val_accuracy: 0.9833
# Learning rate updated  0.000971
# Epoch 31/50
# 28/28 [==============================] - 9s 320ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 0.0343 - val_accuracy: 0.9900
# Epoch 32/50
# 28/28 [==============================] - 9s 316ms/step - loss: 0.0087 - accuracy: 0.9954 - val_loss: 0.0305 - val_accuracy: 0.9867
# Epoch 33/50
# 28/28 [==============================] - 9s 335ms/step - loss: 0.0272 - accuracy: 0.9908 - val_loss: 0.0329 - val_accuracy: 0.9800
# Epoch 34/50
# 28/28 [==============================] - 9s 320ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0299 - val_accuracy: 0.9900
# Epoch 35/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.0112 - accuracy: 0.9954 - val_loss: 0.0325 - val_accuracy: 0.9867
# Epoch 36/50
# 28/28 [==============================] - 9s 319ms/step - loss: 0.0064 - accuracy: 0.9988 - val_loss: 0.0292 - val_accuracy: 0.9833
# Epoch 37/50
# 28/28 [==============================] - 9s 327ms/step - loss: 0.0109 - accuracy: 0.9954 - val_loss: 0.0280 - val_accuracy: 0.9900
# Epoch 38/50
# 28/28 [==============================] - 9s 323ms/step - loss: 0.0140 - accuracy: 0.9965 - val_loss: 0.0326 - val_accuracy: 0.9833
# Epoch 39/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.0253 - val_accuracy: 0.9900
# Epoch 40/50
# 28/28 [==============================] - 9s 319ms/step - loss: 0.0157 - accuracy: 0.9931 - val_loss: 0.0258 - val_accuracy: 0.9833
# Learning rate updated  0.000962
# Epoch 41/50
# 28/28 [==============================] - 9s 321ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 0.9933
# Epoch 42/50
# 28/28 [==============================] - 9s 324ms/step - loss: 0.0074 - accuracy: 0.9965 - val_loss: 0.0292 - val_accuracy: 0.9900
# Epoch 43/50
# 28/28 [==============================] - 9s 328ms/step - loss: 0.0045 - accuracy: 0.9977 - val_loss: 0.0263 - val_accuracy: 0.9900
# Epoch 44/50
# 28/28 [==============================] - 9s 329ms/step - loss: 0.0063 - accuracy: 0.9977 - val_loss: 0.0259 - val_accuracy: 0.9800
# Epoch 45/50
# 28/28 [==============================] - 9s 322ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0248 - val_accuracy: 0.9900
# Epoch 46/50
# 28/28 [==============================] - 9s 319ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9900
# Epoch 47/50
# 28/28 [==============================] - 9s 318ms/step - loss: 0.0121 - accuracy: 0.9954 - val_loss: 0.0243 - val_accuracy: 0.9900
# Epoch 48/50
# 28/28 [==============================] - 9s 319ms/step - loss: 0.0069 - accuracy: 0.9965 - val_loss: 0.0187 - val_accuracy: 0.9900
# Epoch 49/50
# 28/28 [==============================] - 9s 321ms/step - loss: 0.0065 - accuracy: 0.9977 - val_loss: 0.0203 - val_accuracy: 0.9900
# Epoch 50/50
# 28/28 [==============================] - 9s 320ms/step - loss: 0.0078 - accuracy: 0.9977 - val_loss: 0.0204 - val_accuracy: 0.9900

# %% [markdown]
# ## Visualizing the results on the test set after fine tuning

# %%
predictions = model.predict(X_val, batch_size=32)
predictions = tf.where(predictions < 0.5, 0, 1)
print(classification_report(y_val,
                            predictions,
                            target_names=classNames))
# Out:
#               precision    recall  f1-score   support
#
#           OM       0.99      0.99      0.99       152
#          PSG       0.99      0.99      0.99       148
#
#     accuracy                           0.99       300
#    macro avg       0.99      0.99      0.99       300
# weighted avg       0.99      0.99      0.99       300

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_val, predictions)
print(cm)
# Out:
# [[150   2]
#  [  1 147]]

# %%
acc += H_fine.history['accuracy']
val_acc += H_fine.history['val_accuracy']

loss += H_fine.history['loss']
val_loss += H_fine.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.ylim([0.8, 1])
plt.plot([25-1,25-1],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.ylim([0, 1.0])
plt.plot([25-1,25-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.savefig("results.jpg")
plt.show()

# %% [markdown]
# ## Visualizing the results on the test set
#
# To test the model, we consider a sample of $10$ images, $5$ for each class.

# %%
dataset = "/home/igor/Documents/Artificial_Inteligence/Projects/OMXPSG/OMxPSG_CNN/test" # the path for the dataset

# %%
imagesPath = list(paths.list_images(dataset))

# %%
(test, lab_test) = dl.load(imagesPath, verbose=5)
test = test.astype("float") / 255.
# Out:
# [INFO] processed 5/10
# [INFO] processed 10/10

# %%
lab_test = le.fit_transform(lab_test)

# %%
predictions = model.predict(test)
predictions = tf.where(predictions < 0.5, 0, 1)
print(classification_report(lab_test,
                            predictions,
                            target_names=classNames))
# Out:
#               precision    recall  f1-score   support
#
#           OM       0.83      1.00      0.91         5
#          PSG       1.00      0.80      0.89         5
#
#     accuracy                           0.90        10
#    macro avg       0.92      0.90      0.90        10
# weighted avg       0.92      0.90      0.90        10

# %%
preds = predictions.numpy()

# %%
list_pred = [0 if x < 0.5 else 1 for x in preds]

# %%
plt.figure(figsize=(15, 15))
for i in range(10):
    ax = plt.subplot(3, 4, i + 1)
    plt.imshow(cv2.cvtColor(test[i].astype('float32'), cv2.COLOR_BGR2RGB))
    plt.title(classNames[list_pred[i]])
    plt.axis("off")

# %%
model.save('omxpsg.h5')

# %% [markdown]
# ## Conclusions
#
# The fine tuning technique is a good tool when we don’t have enough data. The results confirms it, the loss function curves for the training set and validation are nearly overlapped, that indicates there's no overfit. On the validation set the accuracy has a value of $99\%$, very good result and, on the test set $92\%$, but we’ve considered just $10$ images, the results remain accurate. The model is able to be used for the object detection task  with the composed model (Viola-Jones and CNN classification).
